, 'size': 7, 'hints': 10, 'time': 0.08506512641906738, 'steps': 2243}, {'h': 7, 'size': 7, 'hints': 10, 'time': 0.0808718204498291, 'steps': 2243}, {'h': 8, 'size': 7, 'hints': 10, 'time': 0.37499284744262695, 'steps': 10237}, {'h': 9, 'size': 7, 'hints': 10, 'time': 0.08311605453491211, 'steps': 2243}, {'h': 10, 'size': 7, 'hints': 10, 'time': 1.1394610404968262, 'steps': 25983}])

# %%
# Pivot table: counts grouped by size and hints
pivot = df.pivot_table(index="size", columns="hints", aggfunc='size', fill_value=0)
pivot = pivot // 4

display(pivot)
# Out:
# hints  8   9   10  11  12  13  14
# size
# 6       1   0   5   9   8   5   0
# 7       0   1   1   0   0   0  20

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a new column with readable heuristic labels
df_plot = df.copy()
heuristic_names = {
    None: "DFS",
    2: "MST Heuristic",
    3: "Enhanced Heuristic (2:1)",
    4: "Order Only",
    5: "Fill Only",
    6: "Order Heavy (3:1)",
    7: "Order Heavier (4:1)",
    8: "Order Light (3:2)"
}

df_plot["Heuristic"] = df_plot["h"].map(heuristic_names)


# Plot side-by-side boxplots
plt.figure(figsize=(15, 5))
sns.boxplot(x="Heuristic", y="time", data=df_plot)
plt.title("Solve Time by Heuristic")
plt.xlabel("Heuristic")
plt.ylabel("Time (s)")
plt.yscale('log')  # Logarithmic scale for y-axis
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a new column with readable heuristic labels
df_plot = df.copy()
df_plot["Heuristic"] = df_plot["h"].apply(lambda x: "DFS" if pd.isnull(x) else "MST Heuristic" if x == 2 else "Enhanced Heuristic" if x == 3 else "Enhanced+ Heuristic")

# Plot side-by-side boxplots
plt.figure(figsize=(8, 5))
sns.boxplot(x="Heuristic", y="steps", data=df_plot)
plt.title("Step Count by Heuristic")
plt.xlabel("Heuristic")
plt.ylabel("Steps")
plt.yscale('log')  # Logarithmic scale for y-axis
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Create a new column with readable heuristic labels
df_plot = df.copy()
heuristic_names = {
    None: "DFS",
    2: "MST",
    3: "Enhanced\n(2:1)",
    4: "Order Only\n(1:0)",
    5: "Fill Only\n(0:1)",
    6: "Order Heavy\n(3:1)",
    7: "Order Heavier\n(4:1)",
    8: "Order Light\n(3:2)",
    9: "Order Heaviest\n(10:1)",
    10: "Balanced\n(1:1)"
}

df_plot["Heuristic"] = df_plot["h"].map(heuristic_names)

# Create side-by-side plots
fig, axes = plt.subplots(1, 2, figsize=(20, 5), sharey=False)

# Solve Time boxplot
sns.boxplot(ax=axes[0], x="Heuristic", y="time", data=df_plot)
axes[0].set_title("Solve Time by Algorithm", fontsize=16, fontweight='bold')
axes[0].set_xlabel("Algorithm", fontsize=12, fontweight='bold')
axes[0].set_ylabel("Time (s)", fontsize=12, fontweight='bold')
axes[0].set_yscale('log')
axes[0].grid(False)

# Step Count boxplot
sns.boxplot(ax=axes[1], x="Heuristic", y="steps", data=df_plot)
axes[1].set_title("Step Count by Algorithm", fontsize=16, fontweight='bold')
axes[1].set_xlabel("Algorithm", fontsize=12, fontweight='bold')
axes[1].set_ylabel("Steps", fontsize=12, fontweight='bold')
axes[1].set_yscale('log')
axes[1].grid(False)

plt.tight_layout()
plt.show()

# %%
summary = df_plot.groupby("Heuristic").agg({
    "time": ["mean", "median"],
    "steps": ["mean", "median"]
}).round(6)

# Flatten MultiIndex columns
summary.columns = ['_'.join(col).capitalize() for col in summary.columns]

# Display the result
print(summary.reset_index())
# Out:
#                 Heuristic  Time_mean  Time_median  Steps_mean  Steps_median
# 0         Balanced\n(1:1)   0.372959     0.086307     8653.40        1995.5
# 1                     DFS   1.300619     0.006176   400731.40        3475.0
# 2         Enhanced\n(2:1)   0.023678     0.004199      686.52         156.0
# 3        Fill Only\n(0:1)   0.320673     0.061644     8653.40        1995.5
# 4                     MST   0.626655     0.043806     7121.38         674.0
# 5    Order Heavier\n(4:1)   0.023723     0.004413      686.52         156.0
# 6  Order Heaviest\n(10:1)   0.023343     0.004330      686.52         156.0
# 7      Order Heavy\n(3:1)   0.024986     0.004370      686.52         156.0
# 8      Order Light\n(3:2)   0.078997     0.004826     2145.82         186.0
# 9       Order Only\n(1:0)   0.314185     0.061818     8653.40        1995.5

# %%
# h = None (DFS)
df_dfs = df[df["h"].isnull()]

# h = 2 (MST Heuristic)
df_mst = df[df["h"] == 2]
df_enhanced = df[df["h"] == 3]
print("DFS (h=None):", len(df_dfs))
print("MST Heuristic (h=2):", len(df_mst))
print("Enhanced Heuristic (h=3):", len(df_enhanced))
# Out:
# DFS (h=None): 50
# MST Heuristic (h=2): 50
# Enhanced Heuristic (h=3): 50

# %%
import matplotlib.pyplot as plt

# Get time data for DFS and MST Heuristic
dfs_times = df_dfs["time"].reset_index(drop=True)
mst_times = df_mst["time"].reset_index(drop=True)

# Number of boards (should be equal for both)
n = len(dfs_times)

# Create a line plot to show the time difference for each individual solve
plt.figure(figsize=(10, 6))

# Plot each pair of times (DFS vs MST Heuristic) for each board
for i in range(n):
    plt.plot(["DFS", "MST Heuristic"], [dfs_times[i], mst_times[i]], marker="o", color="gray", alpha=0.6)

plt.title("Solve Time Per Board: DFS vs MST Heuristic")
plt.ylabel("Time (s)")
plt.yscale('log')  # Logarithmic scale for y-axis
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Get time data for DFS and MST Heuristic
dfs_times = df_dfs["steps"].reset_index(drop=True)
mst_times = df_mst["steps"].reset_index(drop=True)

# Number of boards (should be equal for both)
n = len(dfs_times)

# Create a line plot to show the time difference for each individual solve
plt.figure(figsize=(10, 6))

# Plot each pair of times (DFS vs MST Heuristic) for each board
for i in range(n):
    plt.plot(["DFS", "MST Heuristic"], [dfs_times[i], mst_times[i]], marker="o", color="gray", alpha=0.6)

plt.title("Solve Time Per Board: DFS vs MST Heuristic")
plt.ylabel("Time (s)")
plt.yscale('log')  # Logarithmic scale for y-axis
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Reset indexes
dfs_times = df_dfs["time"].reset_index(drop=True)
mst_times = df_mst["time"].reset_index(drop=True)
enhanced_times = df_enhanced["time"].reset_index(drop=True)

dfs_steps = df_dfs["steps"].reset_index(drop=True)
mst_steps = df_mst["steps"].reset_index(drop=True)
enhanced_steps = df_enhanced["steps"].reset_index(drop=True)

n = len(dfs_times)

# Compute means
mean_dfs_time = dfs_times.mean()
mean_mst_time = mst_times.mean()
mean_enhanced_time = enhanced_times.mean()

mean_dfs_steps = dfs_steps.mean()
mean_mst_steps = mst_steps.mean()
mean_enhanced_steps = enhanced_steps.mean()

# Set up the side-by-side plots
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
labels = ["DFS", "MST Heuristic", "A* Enhanced Heuristic"]

# ---------- Time Plot ----------
for i in range(n):
    axes[0].plot(labels,
                 [dfs_times[i], mst_times[i], enhanced_times[i]],
                 marker="o", color="gray", alpha=0.6)

# Average line in bold black
axes[0].plot(labels,
             [mean_dfs_time, mean_mst_time, mean_enhanced_time],
             color="black", linewidth=3, marker="o", label="Mean")

axes[0].set_title("Solve Time Per Board", fontsize=16, fontweight='bold')
axes[0].set_ylabel("Time (s)", fontsize=12, fontweight='bold')
axes[0].set_xlabel("Algorithm", fontsize=12, fontweight='bold')
axes[0].set_yscale('log')
axes[0].grid(True)

# ---------- Steps Plot ----------
for i in range(n):
    axes[1].plot(labels,
                 [dfs_steps[i], mst_steps[i], enhanced_steps[i]],
                 marker="o", color="gray", alpha=0.6)

# Average line in bold black
axes[1].plot(labels,
             [mean_dfs_steps, mean_mst_steps, mean_enhanced_steps],
             color="black", linewidth=3, marker="o", label="Mean")

axes[1].set_title("Step Count Per Board", fontsize=16, fontweight='bold')
axes[1].set_ylabel("Steps", fontsize=12, fontweight='bold')
axes[1].set_xlabel("Algorithm", fontsize=12, fontweight='bold')
axes[1].set_yscale('log')
axes[1].grid(True)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create statistics DataFrame
data = {
    "Algorithm": ["DFS", "MST Heuristic", "Enhanced Heuristic"],
    "Time Mean (s)": [
        df_dfs["time"].mean(),
        df_mst["time"].mean(),
        df_enhanced["time"].mean()
    ],
    "Time Median (s)": [
        df_dfs["time"].median(),
        df_mst["time"].median(),
        df_enhanced["time"].median()
    ],
    "Steps Mean": [
        df_dfs["steps"].mean(),
        df_mst["steps"].mean(),
        df_enhanced["steps"].mean()
    ],
    "Steps Median": [
        df_dfs["steps"].median(),
        df_mst["steps"].median(),
        df_enhanced["steps"].median()
    ]
}

df_stats = pd.DataFrame(data)

# Format for display
df_stats_formatted = df_stats.copy()
df_stats_formatted["Time Mean (s)"] = df_stats_formatted["Time Mean (s)"].map("{:.6f}".format)
df_stats_formatted["Time Median (s)"] = df_stats_formatted["Time Median (s)"].map("{:.6f}".format)
df_stats_formatted["Steps Mean"] = df_stats_formatted["Steps Mean"].map("{:.2f}".format)
df_stats_formatted["Steps Median"] = df_stats_formatted["Steps Median"].map("{:.2f}".format)

# Plot the table
fig, ax = plt.subplots(figsize=(10, 2))
ax.axis('off')

# Create the table in matplotlib
table = ax.table(
    cellText=df_stats_formatted.values,
    colLabels=df_stats_formatted.columns,
    cellLoc='center',
    loc='center'
)

# Style the table
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1, 2)

# Header row styling
for key, cell in table.get_celld().items():
    row, col = key
    if row == 0:
        cell.set_facecolor('lightblue')
        cell.set_text_props(weight='bold')
    else:
        cell.set_facecolor('white')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Separate the original DataFrame into dfs and mst as you've already done
df_dfs = df[df["h"].isnull()]  # DFS (h=None)
df_mst = df[df["h"] == 3]      # MST Heuristic (h=2)

# Reset index to ensure proper alignment before merging
df_dfs = df_dfs.reset_index(drop=True)
df_mst = df_mst.reset_index(drop=True)

# Add the time and steps from df_mst into df_dfs as time_h and time_steps
df_dfs['time_h'] = df_mst['time'].values
df_dfs['steps_h'] = df_mst['steps'].values

# Now df_dfs is renamed as full_df, which contains all the relevant data
full_df = df_dfs
print(full_df)
# Out:
#      h  size  hints       time     steps    time_h  steps_h
# 0  NaN     6      8   0.001323       407  0.027539     1121
# 1  NaN     6     10   0.000498       171  0.005128      194
# 2  NaN     6     11   0.016659     10607  0.001671       64
# 3  NaN     7     14   0.084588     37835  0.003322      119
# 4  NaN     6     11   0.015257     10229  0.004576      198
# 5  NaN     6     11   0.009047      5771  0.002528       87
# 6  NaN     7     14   0.070813     36747  0.003921      120
# 7  NaN     7     14   0.254842     90521  0.007575      278
# 8  NaN     7     14   0.060905     28645  0.014878      446
# 9  NaN     7     14   0.018863     12229  0.004833      158
# 10 NaN     6     11   0.000388       379  0.003035      117
# 11 NaN     6     10   0.000603       585  0.001824       71
# 12 NaN     6     10   0.000610       603  0.010532      353
# 13 NaN     6     10   0.000758       585  0.002087       71
# 14 NaN     7     14   0.001692      1107  0.003932      139
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.colors as mcolors

# Define the colors for each hint value (8 through 14) using a gradient from yellow to red
hint_values = [8, 9, 10, 11, 12, 13, 14]
cmap = plt.cm.get_cmap("YlOrRd", len(hint_values))

# Create color mapping
full_df['color'] = full_df['hints'].apply(lambda x: cmap(hint_values.index(x) / (len(hint_values) - 1)))

# Determine which side of the line each point falls on
above = full_df[full_df['time_h'] > full_df['time']]
below = full_df[full_df['time_h'] < full_df['time']]

# Create the plot
plt.figure(figsize=(8, 8))

# Plot each point
for idx, row in full_df.iterrows():
    marker = 's' if row['size'] == 7 else 'o'
    plt.scatter(row['time'], row['time_h'],
                alpha=0.7,
                c=[row['color']],
                marker=marker,
                edgecolor='k', s=80)

# Diagonal reference line
plt.plot([full_df['time'].min(), full_df['time'].max()],
         [full_df['time'].min(), full_df['time'].max()],
         color='red', linestyle='--')

# Set log scale
plt.xscale("log")
plt.yscale("log")

# Custom color legend
legend_labels = [mpatches.Patch(color=cmap(i / (len(hint_values) - 1)), label=f"{hint_values[i]} hints") for i in range(len(hint_values))]
plt.legend(handles=legend_labels, title="Number of Hints", loc="lower right")

# Labels and title
plt.xlabel("DFS Solve Time (s)")
plt.ylabel("MST Heuristic Solve Time (s)")
plt.title("DFS vs MST Heuristic Solve Times")
plt.grid(True)

# Annotate point counts on each side of the line
plt.text(0.05, 0.95, f"Above line: {len(above)}", transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', color='black', verticalalignment='top')
plt.text(0.05, 0.90, f"Below line: {len(below)}", transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', color='black', verticalalignment='top')

plt.show()

# Print the total number of data points
print(f"Total points in full_df: {len(full_df)}")
# Out:
# /var/folders/89/94_2tlgd02v9284r_87pkg2h0000gp/T/ipykernel_5085/1937392952.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap("YlOrRd", len(hint_values))
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 11
#       8 cmap = plt.cm.get_cmap("YlOrRd", len(hint_values))
#      10 # Create color mapping
# ---> 11 full_df['color'] = full_df['hints'].apply(lambda x: cmap(hint_values.index(x) / (len(hint_values) - 1)))
#      13 # Determine which side of the line each point falls on
#      14 above = full_df[full_df['time_h'] > full_df['time']]
#
# NameError: name 'full_df' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Define the hint values (8 through 14)
hint_values = [8, 9, 10, 11, 12, 13, 14]

# Create a gradient colormap from yellow to red
cmap = plt.cm.get_cmap("YlOrRd", len(hint_values))

# Create a color mapping for each hint value
full_df['color'] = full_df['hints'].apply(lambda x: cmap(hint_values.index(x) / (len(hint_values) - 1)) if x in hint_values else '#000000')

# Determine which side of the line each point falls on
above = full_df[full_df['steps_h'] > full_df['steps']]
below = full_df[full_df['steps_h'] < full_df['steps']]

# Create the figure
plt.figure(figsize=(8, 8))

# Plot each point
for idx, row in full_df.iterrows():
    marker = 's' if row['size'] == 7 else 'o'
    plt.scatter(row['steps'], row['steps_h'], 
                alpha=0.7, 
                c=[row['color']], 
                marker=marker, 
                edgecolor='k', s=80)

# Plot the red diagonal line
plt.plot([full_df['steps'].min(), full_df['steps'].max()],
         [full_df['steps'].min(), full_df['steps'].max()],
         color='red', linestyle='--')

# Set log scale
plt.xscale("log")
plt.yscale("log")

# Create custom legend
legend_labels = [mpatches.Patch(color=cmap(i / (len(hint_values) - 1)), label=f"{hint_values[i]} hints") for i in range(len(hint_values))]
plt.legend(handles=legend_labels, title="Number of Hints", loc="lower right")

# Labels and title
plt.xlabel("DFS Steps")
plt.ylabel("MST Heuristic Steps")
plt.title("DFS vs MST Heuristic Steps")
plt.grid(True)

# Annotate counts in bold black
plt.text(0.05, 0.95, f"Above line: {len(above)}", transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', color='black', verticalalignment='top')
plt.text(0.05, 0.90, f"Below line: {len(below)}", transform=plt.gca().transAxes,
         fontsize=12, fontweight='bold', color='black', verticalalignment='top')

plt.show()

# Print total number of data points
print(f"Total points in full_df: {len(full_df)}")
# Out:
# /var/folders/89/94_2tlgd02v9284r_87pkg2h0000gp/T/ipykernel_87670/4138413126.py:9: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap("YlOrRd", len(hint_values))
# Total points in full_df: 50

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.lines as mlines

# Define the hint values (8 through 14)
hint_values = [8, 9, 10, 11, 12, 13, 14]
cmap = plt.cm.get_cmap("YlOrRd", len(hint_values))

# Map hint values to colors
full_df['color'] = full_df['hints'].apply(lambda x: cmap(hint_values.index(x) / (len(hint_values) - 1)) if x in hint_values else '#000000')

# Set up figure and axes
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))

# ---------- Plot 1: Time ----------
for idx, row in full_df.iterrows():
    marker = 's' if row['size'] == 7 else 'o'
    ax1.scatter(row['time'], row['time_h'], 
                alpha=0.7, 
                c=[row['color']], 
                marker=marker, 
                edgecolor='k', s=80)

ax1.plot([full_df['time'].min(), full_df['time'].max()],
         [full_df['time'].min(), full_df['time'].max()],
         color='red', linestyle='--')

ax1.set_xscale("log")
ax1.set_yscale("log")
ax1.set_xlabel("DFS Solve Time (s)", fontsize=13, fontweight='bold')
ax1.set_ylabel("A* Enhanced Heuristic Solve Time (s)", fontsize=13, fontweight='bold')
ax1.set_title("DFS vs A* Enhanced Heuristic Solve Times", fontsize=16, fontweight='bold')
ax1.grid(True)

# Count and annotate
above = (full_df['time_h'] > full_df['time']).sum()
below = (full_df['time_h'] < full_df['time']).sum()
ax1.text(0.05, 0.95, f"Above line: {above}", transform=ax1.transAxes,
         fontsize=12, fontweight='bold', color='black', va='top')
ax1.text(0.05, 0.90, f"Below line: {below}", transform=ax1.transAxes,
         fontsize=12, fontweight='bold', color='black', va='top')

# ---------- Plot 2: Steps ----------
for idx, row in full_df.iterrows():
    marker = 's' if row['size'] == 7 else 'o'
    ax2.scatter(row['steps'], row['steps_h'], 
                alpha=0.7, 
                c=[row['color']], 
                marker=marker, 
                edgecolor='k', s=80)

ax2.plot([full_df['steps'].min(), full_df['steps'].max()],
         [full_df['steps'].min(), full_df['steps'].max()],
         color='red', linestyle='--')

ax2.set_xscale("log")
ax2.set_yscale("log")
ax2.set_xlabel("DFS Steps", fontsize=13, fontweight='bold')
ax2.set_ylabel("A* Enhanced Heuristic Steps", fontsize=13, fontweight='bold')
ax2.set_title("DFS vs A* Enhanced Heuristic Steps", fontsize=16, fontweight='bold')
ax2.grid(True)

# Count and annotate
above = (full_df['steps_h'] > full_df['steps']).sum()
below = (full_df['steps_h'] < full_df['steps']).sum()
ax2.text(0.05, 0.95, f"Above line: {above}", transform=ax2.transAxes,
         fontsize=12, fontweight='bold', color='black', va='top')
ax2.text(0.05, 0.90, f"Below line: {below}", transform=ax2.transAxes,
         fontsize=12, fontweight='bold', color='black', va='top')

# ---------- Legends ----------
# Hint color legend
hint_legend = [mpatches.Patch(color=cmap(i / (len(hint_values) - 1)), label=f"{hint_values[i]} hints") for i in range(len(hint_values))]

# Shape legend for size
circle_patch = mlines.Line2D([], [], color='black', marker='o', linestyle='None',
                             markersize=10, label='6x6 Board', markerfacecolor='gray')
square_patch = mlines.Line2D([], [], color='black', marker='s', linestyle='None',
                             markersize=10, label='7x7 Board', markerfacecolor='gray')

# Combine and show all legends
all_handles = hint_legend + [square_patch, circle_patch]
fig.legend(handles=all_handles, loc='lower center', ncol=9, title="Legend", frameon=False)

plt.tight_layout(rect=[0, 0.04, 1, 1])  # leave space for legend
plt.show()
# Out:
# /var/folders/89/94_2tlgd02v9284r_87pkg2h0000gp/T/ipykernel_5085/33039628.py:8: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap("YlOrRd", len(hint_values))
